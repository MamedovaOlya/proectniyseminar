# %%
import pandas as pd

# %%
df = pd.read_csv("number-of-deaths-by-risk-factor.csv", sep=",")

# %%
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6463     Zimbabwe  ZWE  2013
# 6464     Zimbabwe  ZWE  2014
# 6465     Zimbabwe  ZWE  2015
# 6466     Zimbabwe  ZWE  2016
# 6467     Zimbabwe  ZWE  2017
#
#       Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 0                                           7554.049543
# 1                                           7359.676749
# 2                                           7650.437822
# 3                                          10270.731383
# 4                                          11409.177112
# ...                                                 ...
# 6463                                        4254.282075
# 6464                                        4098.769691
# 6465                                        3921.291358
# ...

# %%
df["Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)"].min()
# Out:
# 0.00865019307122983

# %%
df["Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 279.03169197819534

# %%
df["Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 160.1965364741019

# %%
df["Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 252.4990983515709

# %%
df["Deaths - Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 1091.6711527653642

# %%
df["Deaths - Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 102.42830700851498

# %%
df["Deaths - Child wasting - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 730.3462374675296

# %%
df["Deaths - Air pollution - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 6125.098027840131

# %%
df["Entity"].describe()
# Out:
# count           6468
# unique           231
# top       Bangladesh
# freq              28
# Name: Entity, dtype: object

# %%
df.value_counts()
# Out:
# Entity       Code  Year  Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)  Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)  Deaths - Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)  Deaths - Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)  Deaths - Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)  Deaths - Child wasting - Sex: Both - Age: All Ages (Number)  Deaths - Child stunting - Sex: Both - Age: All Ages (Number)  Deaths - Low birth weight for gestation - Sex: Both - Age: All Ages (Number)  Deaths - Secondhand smoke - Sex: Both - Age: All Ages (Number)  Deaths - Alcohol use - Sex: Both - Age: All Ages (Number)  Deaths - Drug use - Sex: Both - Age: All Ages (Number)  Deaths - Diet low in fruits - Sex: Both - Age: All Ages (Number)  Deaths - Diet low in vegetables - Sex: Both - Age: All Ages (Number)  Deaths 
# ...

# %%
df[1:45]
# Out:
#          Entity Code  Year  \
# 1   Afghanistan  AFG  1991
# 2   Afghanistan  AFG  1992
# 3   Afghanistan  AFG  1993
# 4   Afghanistan  AFG  1994
# 5   Afghanistan  AFG  1995
# 6   Afghanistan  AFG  1996
# 7   Afghanistan  AFG  1997
# 8   Afghanistan  AFG  1998
# 9   Afghanistan  AFG  1999
# 10  Afghanistan  AFG  2000
# 11  Afghanistan  AFG  2001
# 12  Afghanistan  AFG  2002
# 13  Afghanistan  AFG  2003
# 14  Afghanistan  AFG  2004
# 15  Afghanistan  AFG  2005
# 16  Afghanistan  AFG  2006
# 17  Afghanistan  AFG  2007
# 18  Afghanistan  AFG  2008
# 19  Afghanistan  AFG  2009
# 20  Afghanistan  AFG  2010
# 21  Afghanistan  AFG  2011
# 22  Afghanistan  AFG  2012
# 23  Afghanistan  AFG  2013
# 24  Afghanistan  AFG  2014
# 25  Afghanistan  AFG  2015
# 26  Afghanistan  AFG  2016
# 27  Afghanistan  AFG  2017
# 28      Albania  ALB  1990
# 29      Albania  ALB  1991
# 30      Albania  ALB  1992
# 31      Albania  ALB  1993
# 32      Albania  ALB  1994
# 33      Albania  ALB  1995
# ...

# %%
df[df['Deaths - Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)'] > 3000]
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6463     Zimbabwe  ZWE  2013
# 6464     Zimbabwe  ZWE  2014
# 6465     Zimbabwe  ZWE  2015
# 6466     Zimbabwe  ZWE  2016
# 6467     Zimbabwe  ZWE  2017
#
#       Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 0                                           7554.049543
# 1                                           7359.676749
# 2                                           7650.437822
# 3                                          10270.731383
# 4                                          11409.177112
# ...                                                 ...
# 6463                                        4254.282075
# 6464                                        4098.769691
# 6465                                        3921.291358
# ...

# %%
df_child = df[df['Deaths - Child wasting - Sex: Both - Age: All Ages (Number)'] > 22000]

# %%
df_child.value_counts(df_child['Entity'])
# Out:
# Entity
# North Africa and Middle East                        28
# Pakistan                                            28
# India                                               28
# Indonesia                                           28
# Latin America and Caribbean                         28
# Low SDI                                             28
# Low-middle SDI                                      28
# Madagascar                                          28
# World                                               28
# Democratic Republic of Congo                        28
# Middle SDI                                          28
# Chad                                                28
# Niger                                               28
# Nigeria                                             28
# Ethiopia                                            28
# Central Sub-Saharan Africa                          28
# Eastern Sub-Saharan Africa                          28
# ...

# %%
df_air = df[df['Deaths - Air pollution - Sex: Both - Age: All Ages (Number)'] > 30000]

# %%
df_air.value_counts(df_air['Entity'])
# Out:
# Entity
# World                                               28
# Western Sub-Saharan Africa                          28
# Latin America and Caribbean                         28
# Japan                                               28
# Indonesia                                           28
# India                                               28
# High-middle SDI                                     28
# High-income Asia Pacific                            28
# High-income                                         28
# High SDI                                            28
# Germany                                             28
# Ethiopia                                            28
# Egypt                                               28
# Eastern Sub-Saharan Africa                          28
# Eastern Europe                                      28
# East Asia                                           28
# Democratic Republic of Congo                        28
# ...

# %%
df_breath = df[df['Deaths - Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)'] > 250]

# %%
df_brath.value_counts(df_brath['Entity'])
# Out:
# Entity
# Low-middle SDI                                      28
# World                                               28
# Latin America and Caribbean                         28
# India                                               28
# Middle SDI                                          28
# Ethiopia                                            28
# Niger                                               28
# Nigeria                                             28
# North Africa and Middle East                        28
# Pakistan                                            28
# Eastern Sub-Saharan Africa                          28
# Democratic Republic of Congo                        28
# Low SDI                                             28
# South Asia                                          28
# Southeast Asia                                      28
# Southeast Asia, East Asia, and Oceania              28
# Southern Sub-Saharan Africa                         28
# ...

# %%
gdf = df[df["Entity"] == "Russia"]
gdf
# Out:
#       Entity Code  Year  \
# 4704  Russia  RUS  1990
# 4705  Russia  RUS  1991
# 4706  Russia  RUS  1992
# 4707  Russia  RUS  1993
# 4708  Russia  RUS  1994
# 4709  Russia  RUS  1995
# 4710  Russia  RUS  1996
# 4711  Russia  RUS  1997
# 4712  Russia  RUS  1998
# 4713  Russia  RUS  1999
# 4714  Russia  RUS  2000
# 4715  Russia  RUS  2001
# 4716  Russia  RUS  2002
# 4717  Russia  RUS  2003
# 4718  Russia  RUS  2004
# 4719  Russia  RUS  2005
# 4720  Russia  RUS  2006
# 4721  Russia  RUS  2007
# 4722  Russia  RUS  2008
# 4723  Russia  RUS  2009
# 4724  Russia  RUS  2010
# 4725  Russia  RUS  2011
# 4726  Russia  RUS  2012
# 4727  Russia  RUS  2013
# 4728  Russia  RUS  2014
# 4729  Russia  RUS  2015
# 4730  Russia  RUS  2016
# 4731  Russia  RUS  2017
#
#       Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# 4704                                         895.378366
# 4705                                         805.880624
# ...

# %%
gdf["Deaths - Unsafe sanitation - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 351.85075141015705

# %%
gdf["Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 389.2784517205122

# %%
gdf["Deaths - No access to handwashing facility - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 622.87546782117

# %%
gdf["Deaths - Child wasting - Sex: Both - Age: All Ages (Number)"].median()
# Out:
# 1709.0459201321753
